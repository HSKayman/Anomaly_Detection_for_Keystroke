# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("DSL-StrongPasswordData.csv")
df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# ...

# %%
df.tail(5)
# Out:
#       subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 20395    s057             8   46    0.0884       0.0685      -0.0199  0.1095
# 20396    s057             8   47    0.0655       0.0630      -0.0025  0.0910
# 20397    s057             8   48    0.0939       0.1189       0.0250  0.1008
# 20398    s057             8   49    0.0923       0.1294       0.0371  0.0913
# 20399    s057             8   50    0.0596       0.1310       0.0714  0.0992
#
#        DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 20395  0.1290  0.0195  0.0945  ...  0.1219  0.1383  0.0164  0.0820  0.1329
# 20396  0.1148  0.0238  0.0916  ...  0.1008  0.0512 -0.0496  0.1037  0.0868
# 20397  0.1122  0.0114  0.0721  ...  0.0913  0.1169  0.0256  0.0689  0.1311
# 20398  0.0990  0.0077  0.0992  ...  0.0882  0.0821 -0.0061  0.0576  0.0697
# 20399  0.1103  0.0111  0.0998  ...  0.0969  0.0784 -0.0185  0.0790  0.1133
#
# ...

# %%
df.describe().T[3:]
columns=df.columns

# %%
DD=[]
UD=[]
H=[]
for i in columns:
    if 'DD' in i:
        DD.append(i)
    elif 'UD' in i:
        UD.append(i)
    elif 'H' in i:
        H.append(i)

# %%
df.groupby('subject')[DD].describe().T
# Out:
# subject                  s002        s003        s004        s005        s007  \
# DD.period.t count  400.000000  400.000000  400.000000  400.000000  400.000000
#             mean     0.169556    0.169161    0.201065    0.278240    0.176463
#             std      0.074073    0.103577    0.098102    0.130109    0.077947
#             min      0.023700    0.027600    0.101900    0.130600    0.085000
#             25%      0.127700    0.117900    0.147200    0.210550    0.129250
# ...                       ...         ...         ...         ...         ...
# DD.l.Return min      0.153000    0.175500    0.169300    0.299200    0.164600
#             25%      0.205150    0.219725    0.196150    0.358225    0.191300
#             50%      0.228350    0.233850    0.211300    0.381900    0.207050
#             75%      0.264625    0.255800    0.229550    0.420625    0.232325
#             max      1.266300    1.498800    1.021500    1.316000    1.390100
#
# ...

# %%
df.groupby('subject')[UD].describe().T
# Out:
# subject                  s002        s003        s004        s005        s007  \
# UD.period.t count  400.000000  400.000000  400.000000  400.000000  400.000000
#             mean     0.062598    0.011868    0.097319    0.196278    0.081252
#             std      0.069871    0.118468    0.096920    0.131479    0.076874
#             min     -0.048400   -0.235800    0.001300    0.042700   -0.013600
#             25%      0.026700   -0.044200    0.046825    0.126300    0.038425
# ...                       ...         ...         ...         ...         ...
# UD.l.Return min      0.058500    0.097500    0.084300    0.217300    0.066900
#             25%      0.114700    0.117600    0.104700    0.270825    0.099100
#             50%      0.132250    0.128500    0.116250    0.293450    0.110600
#             75%      0.160225    0.148850    0.134050    0.332175    0.128175
#             max      1.168100    1.418800    0.931700    1.233900    1.282400
#
# ...

# %%
df.groupby('subject')[H].describe().T
# Out:
# subject               s002        s003        s004        s005        s007  \
# H.period count  400.000000  400.000000  400.000000  400.000000  400.000000
#          mean     0.106958    0.157293    0.103745    0.081963    0.095211
#          std      0.024979    0.042576    0.016934    0.013252    0.014978
#          min      0.010300    0.037200    0.042000    0.041500    0.047800
#          25%      0.092700    0.130700    0.094500    0.073700    0.084200
# ...                    ...         ...         ...         ...         ...
# H.Return min      0.019600    0.018200    0.011100    0.050400    0.015300
#          25%      0.071000    0.089000    0.068900    0.083400    0.074350
#          50%      0.079700    0.098350    0.075000    0.090500    0.084700
#          75%      0.091150    0.109075    0.082175    0.099000    0.094800
#          max      0.202700    0.180800    0.114300    0.148300    0.129300
#
# ...

# %%
df_1=df.groupby('subject')[H].mean()
df_2=df.groupby('subject')[DD].mean()
df_3=df.groupby('subject')[UD].mean()

# %%
import random 
random_person=[random.randint(0, len(df_1.index)) for i in range(8)]
random_person
# Out:
# [26, 43, 34, 35, 48, 8, 39, 46]

# %%
colour=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

# %%
df_1.iloc[random_person]
# Out:
#          H.period       H.t       H.i       H.e    H.five  H.Shift.r  \
# subject
# s051     0.102949  0.071980  0.075004  0.085157  0.069150   0.083997
# s042     0.102486  0.058812  0.067195  0.074015  0.057488   0.067759
# s055     0.094679  0.106532  0.086479  0.116801  0.097751   0.112879
# s043     0.060295  0.070842  0.063328  0.083608  0.059974   0.049900
# s047     0.086283  0.083445  0.074024  0.075369  0.084023   0.094726
# s035     0.053406  0.076909  0.057120  0.093775  0.075921   0.111304
# s007     0.095211  0.074890  0.076754  0.089969  0.069239   0.091274
# s050     0.084314  0.062744  0.072154  0.080460  0.066836   0.106815
#
#               H.o       H.a       H.n       H.l  H.Return
# subject
# s051     0.071923  0.082949  0.097739  0.081002  0.059906
# s042     0.091308  0.073991  0.136343  0.126178  0.121442
# s055     0.087204  0.090208  0.063884  0.101798  0.118211
# s043     0.060133  0.104249  0.054198  0.052379  0.046770
# ...

# %%
import seaborn as sns
#import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
fig,ax=plt.subplots(figsize=(30,15))
colour=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
k=0

for i,j in df_1.iloc[random_person].iterrows():
    ax.plot(df_1.iloc[random_person].columns,j,c=colour[k])
    k+=1
handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=list(df_1.iloc[random_person].index)[k], markersize=10) for k,v in enumerate(colour)]
ax.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
fig,ax=plt.subplots(figsize=(30,15))
colour=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
k=0

for i,j in df_2.iloc[random_person].iterrows():
    ax.plot(df_2.iloc[random_person].columns,j,c=colour[k])
    k+=1
handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=list(df_2.iloc[random_person].index)[k], markersize=10) for k,v in enumerate(colour)]
ax.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
fig,ax=plt.subplots(figsize=(30,15))
colour=['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']
k=0

for i,j in df_3.iloc[random_person].iterrows():
    ax.plot(df_3.iloc[random_person].columns,j,c=colour[k])
    k+=1
handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=list(df_3.iloc[random_person].index)[k], markersize=10) for k,v in enumerate(colour)]
ax.legend(title='color', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
df['subject']=df['subject'].astype('category')

# %%
df['subject']=df['subject'].cat.codes

# %%
df
# Out:
#        subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0            0             1    1    0.1491       0.3979       0.2488  0.1069
# 1            0             1    2    0.1111       0.3451       0.2340  0.0694
# 2            0             1    3    0.1328       0.2072       0.0744  0.0731
# 3            0             1    4    0.1291       0.2515       0.1224  0.1059
# 4            0             1    5    0.1249       0.2317       0.1068  0.0895
# ...        ...           ...  ...       ...          ...          ...     ...
# 20395       50             8   46    0.0884       0.0685      -0.0199  0.1095
# 20396       50             8   47    0.0655       0.0630      -0.0025  0.0910
# 20397       50             8   48    0.0939       0.1189       0.0250  0.1008
# 20398       50             8   49    0.0923       0.1294       0.0371  0.0913
# 20399       50             8   50    0.0596       0.1310       0.0714  0.0992
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix 
from sklearn import svm
df=df.drop(['sessionIndex','rep'],axis=1)
X=df.iloc[:,1:].values
y=df.iloc[:,[0]].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
svc_params = {"C": [0.0001, 0.001, 0.1, 1, 5, 10 ,50 ,100],
             "gamma": [0.0001, 0.001, 0.1, 1, 5, 10 ,50 ,100]}
svc = SVC()
svc_cv_model = GridSearchCV(svc, svc_params, 
                         cv = 10, 
                         n_jobs = -1,
                         verbose = 2)

svc_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 63.1min
# [Parallel(n_jobs=-1)]: Done 640 out of 640 | elapsed: 96.2min finished
# C:\Users\suca\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# GridSearchCV(cv=10, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.1, 1, 5, 10, 50, 100],
#                          'gamma': [0.0001, 0.001, 0.1, 1, 5, 10, 50, 100]},
#              verbose=2)

# %%
print(svc_cv_model.best_params_)
# Out:
# {'C': 50, 'gamma': 1}

# %%
svc_tuned = SVC(C = 50, gamma = 1).fit(X_train, y_train)
# Out:
# C:\Users\suca\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
y_pred = svc_tuned.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 97,   2,   0, ...,   0,   0,   0],
#        [  1, 101,   3, ...,   0,   0,   0],
#        [  2,   1, 105, ...,   0,   2,   0],
#        ...,
#        [  1,   0,   0, ..., 124,   2,   0],
#        [  0,   0,   0, ...,   0,  90,   2],
#        [  1,   0,   0, ...,   0,   0,  80]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8790849673202614
